# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import build_all
from data import load_statcast

# %%
data = build_all(live=False)

# %%
statcast_clean  = data['statcast_clean']
pitch_type_summ = data['pitch_type_summ']
pitcher_summ    = data['pitcher_summ']
pitcher_summ_r  = data['pitcher_summ_r']
pitcher_summ_l  = data['pitcher_summ_l']
pitch_type_r  = data['pitch_type_r']
pitch_type_l  = data['pitch_type_l']

# %%
pitch_type_r.head()
# Out:
#         player_name  game_year pitch_type  release_speed     pfx_x     pfx_z  \
# 0  Wainwright, Adam       2021         CH      82.729744 -1.152821  0.643179
# 1  Wainwright, Adam       2022         CH      82.182540 -1.192593  0.668889
# 2  Wainwright, Adam       2023         CH      81.431461 -1.168652  0.729663
# 3     Greinke, Zack       2021         CH      86.350791 -1.065747  0.371793
# 4     Greinke, Zack       2022         CH      86.468984 -1.067433  0.317032
#
#      n
# 0  195
# 1  189
# 2   89
# 3  569
# 4  374
